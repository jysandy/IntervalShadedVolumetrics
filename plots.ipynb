# %%
ms_vs_step_count = [(1, 4.05), (2, 4.63), (3, 5.56), (4, 6.10), (5, 6.54), (6, 7.04), (7, 7.75), (8, 8.40), (9, 9.17), (10, 9.80)]

# %%
ms_vs_step_count_1000 = [(1, 6.17), (2, 7.30), (3, 8.55), (4, 10.0), (5, 11.36), (6, 12.82), (7, 14.29), (8, 15.62), (9, 17.24), (10, 18.52)]

# %%
ms_vs_step_count_2000 = [(1, 10.31), (2, 12.99), (3, 16.13), (4, 18.52), (5, 21.74), (6, 24.39), (7, 27.78), (8, 30.3), (9, 33.33), (10, 35.71)]

# %%
list_plot(ms_vs_step_count, plotjoined=True, legend_label='500 particles')  \
+ list_plot(ms_vs_step_count_1000, plotjoined=True, color='purple', legend_label='1000 particles') \
+ list_plot(ms_vs_step_count_2000, plotjoined=True, color='red', legend_label='2000 particles', \
            axes_labels=['steps _', 'ms/frame'], axes_labels_size=0.8)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
ms_vs_particle_count_20m = [(500, 4.12), (1000, 5.81), (2000, 10.31), (5000, 24.39), (10000, 47.62), \
                               (25000, 125), (50000, 250)]

# %%
ms_vs_particle_count_40m = [(500, 1.70), (1000, 2.63), (2000, 4.17), (5000, 7.35), (10000, 13.70), \
                               (25000, 32.26), (50000, 62.50)]

# %%
ms_vs_particle_count_60m = [(500, 1.06), (1000, 1.49), (2000, 2.54), (5000, 4.62), (10000, 7.04), \
                               (25000, 15.62), (50000, 30.30)]

# %%
list_plot(ms_vs_particle_count_20m, plotjoined=True, color='red', legend_label='20m away') \
+ list_plot(ms_vs_particle_count_40m, plotjoined=True, color='blue', legend_label='40m away') \
+ list_plot(ms_vs_particle_count_60m, plotjoined=True, color='green', legend_label='60m away', \
           axes_labels=['particles           _', 'ms/frame'], axes_labels_size=0.8)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
ms_vs_extinction_falloff_15 = [(1, 1.44), (2, 1.91), (4, 1.89),\
                                (6, 2.33), (8, 2.32), (10, 2.33)]

# %%
ms_vs_extinction_falloff_50 = [(1, 1.47), (2, 1.96), (4, 2.27),\
                                (6, 2.24), (8, 2.28), (10, 2.27)]

# %%
ms_vs_extinction_falloff_100 = [(1, 1.56), (2, 1.89), (4, 1.86), (6, 2.24), (8, 2.28), (10, 2.24)]

# %%
list_plot(ms_vs_extinction_falloff_15, plotjoined=True, color='green', xmax=10, ymax=10, \
         axes_labels=['falloff parameter f                                           _', 'ms/frame'], axes_labels_size=0.8)#\
#+ list_plot(ms_vs_extinction_falloff_50, plotjoined=True, color='blue', legend_label = 'Extinction 50')\
#+ list_plot(ms_vs_extinction_falloff_100, plotjoined=True, color='red', legend_label = 'Extinction 100', )
# Out:
# Graphics object consisting of 1 graphics primitive
